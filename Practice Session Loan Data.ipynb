# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Glamorous9754/Practice-in-Jupyter/main/Data%20Files/loan_data.csv'
df = pd.read_csv(url)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male     Yes          1      Graduate            No             4583
# 1   Male     Yes          0      Graduate           Yes             3000
# 2   Male     Yes          0  Not Graduate            No             2583
# 3   Male      No          0      Graduate            No             6000
# 4   Male     Yes          0  Not Graduate            No             2333
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             1508.0         128             360.0             1.0
# 1                0.0          66             360.0             1.0
# 2             2358.0         120             360.0             1.0
# 3                0.0         141             360.0             1.0
# 4             1516.0          95             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Rural           N
# 1         Urban           Y
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             376 non-null    object
#  1   Married            381 non-null    object
#  2   Dependents         373 non-null    object
#  3   Education          381 non-null    object
#  4   Self_Employed      360 non-null    object
#  5   ApplicantIncome    381 non-null    int64
#  6   CoapplicantIncome  381 non-null    float64
#  7   LoanAmount         381 non-null    int64
#  8   Loan_Amount_Term   370 non-null    float64
#  9   Credit_History     351 non-null    float64
#  10  Property_Area      381 non-null    object
#  11  Loan_Status        381 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 35.8+ KB

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ApplicantIncome          381 non-null    int64
#  1   CoapplicantIncome        381 non-null    float64
#  2   LoanAmount               381 non-null    int64
#  3   Loan_Amount_Term         370 non-null    float64
#  4   Credit_History           351 non-null    float64
#  5   Gender_Male              381 non-null    bool
#  6   Married_Yes              381 non-null    bool
#  7   Dependents_1             381 non-null    bool
#  8   Dependents_2             381 non-null    bool
#  9   Dependents_3+            381 non-null    bool
#  10  Education_Not Graduate   381 non-null    bool
#  11  Self_Employed_Yes        381 non-null    bool
#  12  Property_Area_Semiurban  381 non-null    bool
#  13  Property_Area_Urban      381 non-null    bool
#  14  Loan_Status_Y            381 non-null    bool
# dtypes: bool(10), float64(3), int64(2)
# memory usage: 18.7 KB

# %%
# fill all the missing values with the mean value of the respected columns
df.fillna(df.mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ApplicantIncome          381 non-null    int64
#  1   CoapplicantIncome        381 non-null    float64
#  2   LoanAmount               381 non-null    int64
#  3   Loan_Amount_Term         381 non-null    float64
#  4   Credit_History           381 non-null    float64
#  5   Gender_Male              381 non-null    bool
#  6   Married_Yes              381 non-null    bool
#  7   Dependents_1             381 non-null    bool
#  8   Dependents_2             381 non-null    bool
#  9   Dependents_3+            381 non-null    bool
#  10  Education_Not Graduate   381 non-null    bool
#  11  Self_Employed_Yes        381 non-null    bool
#  12  Property_Area_Semiurban  381 non-null    bool
#  13  Property_Area_Urban      381 non-null    bool
#  14  Loan_Status_Y            381 non-null    bool
# dtypes: bool(10), float64(3), int64(2)
# memory usage: 18.7 KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       381.000000         381.000000  381.000000        381.000000
# mean       3579.845144        1277.275381  104.986877        340.864865
# std        1419.813818        2340.818114   28.358464         67.549811
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2600.000000           0.000000   90.000000        360.000000
# 50%        3333.000000         983.000000  110.000000        360.000000
# 75%        4288.000000        2016.000000  127.000000        360.000000
# max        9703.000000       33837.000000  150.000000        480.000000
#
#        Credit_History
# count      381.000000
# mean         0.837607
# std          0.354459
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
import seaborn as sns

sns.boxplot(df['ApplicantIncome'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['CoapplicantIncome'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['LoanAmount'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['ApplicantIncome'])
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ApplicantIncome          381 non-null    int64
#  1   CoapplicantIncome        381 non-null    float64
#  2   LoanAmount               381 non-null    int64
#  3   Loan_Amount_Term         381 non-null    float64
#  4   Credit_History           381 non-null    float64
#  5   Gender_Male              381 non-null    bool
#  6   Married_Yes              381 non-null    bool
#  7   Dependents_1             381 non-null    bool
#  8   Dependents_2             381 non-null    bool
#  9   Dependents_3+            381 non-null    bool
#  10  Education_Not Graduate   381 non-null    bool
#  11  Self_Employed_Yes        381 non-null    bool
#  12  Property_Area_Semiurban  381 non-null    bool
#  13  Property_Area_Urban      381 non-null    bool
#  14  Loan_Status_Y            381 non-null    bool
# dtypes: bool(10), float64(3), int64(2)
# memory usage: 18.7 KB

# %%
import matplotlib.pyplot as plt

dfy= df[['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']]
Q1 = dfy.quantile(0.25)
Q3 = dfy.quantile(0.75)
IQR = Q3 - Q1

outliers = ((dfy < (Q1 - 1.5 * IQR)) |(dfy > (Q3 + 1.5 * IQR))).any(axis=1)
outliers_indices = dfy[outliers].index

outliers_count = outliers.sum()
# outliers_count

plt.figure(figsize=(20,10))
for i,column in enumerate(dfy.columns,1):
    plt.subplot(2,4,i)
    sns.boxplot(data=dfy[column])
    plt.title(column)
plt.tight_layout()
plt.show()

# %%
df_filtered = dfy
for feature in Q1.index:
    LB = Q1[feature] - 1.5 * IQR[feature]
    UB = Q3[feature] + 1.5 * IQR[feature]
    df_filtered[feature] = df_filtered[feature].clip(lower=LB, upper=UB)

plt.figure(figsize=(20,10))
for i,column in enumerate(df_filtered.columns,1):
    plt.subplot(2,4,i)
    sns.boxplot(data=df_filtered[column])
    plt.title(column)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ayan1\AppData\Local\Temp\ipykernel_18452\3192160562.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered[feature] = df_filtered[feature].clip(lower=LB, upper=UB)

# %%
df[4,10][,]
# Out:
#   Cell In[38], line 1
#     df[4,10][,]
#              ^
# SyntaxError: invalid syntax

# %%
# insert all the last 10 columns of df to df_filter

df_filteredx = pd.concat([df_filtered, df.iloc[4,-14:]], axis=1)

# df_filtered.info()
# df_filtered.corr()
# plt.figure(figsize=(20,15))

# %%
df_filteredx = df.iloc[4:14]
df_filteredx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 4 to 13
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ApplicantIncome          10 non-null     int64
#  1   CoapplicantIncome        10 non-null     float64
#  2   LoanAmount               10 non-null     int64
#  3   Loan_Amount_Term         10 non-null     float64
#  4   Credit_History           10 non-null     float64
#  5   Gender_Male              10 non-null     bool
#  6   Married_Yes              10 non-null     bool
#  7   Dependents_1             10 non-null     bool
#  8   Dependents_2             10 non-null     bool
#  9   Dependents_3+            10 non-null     bool
#  10  Education_Not Graduate   10 non-null     bool
#  11  Self_Employed_Yes        10 non-null     bool
#  12  Property_Area_Semiurban  10 non-null     bool
#  13  Property_Area_Urban      10 non-null     bool
#  14  Loan_Status_Y            10 non-null     bool
# dtypes: bool(10), float64(3), int64(2)
# memory usage: 632.0 bytes
